# %%
"""
1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators. 
Ans:
*       Expression
'hello' Value
-87.8   Value
-       Expression
/       Expression
+       Expression
6       Value 



2. What is the difference between string and variable?
Ans: Stings are the vlaues to be used in the program. And it is one of the data type in python like other programing languages. 
        Strings are the values to be enclosed in quotes.
     Vairable are used to store information of any data type. I a variable spaces and special characters (other than '_') are 
     not allowed.



3. Describe three different data types.
Ans : int   : stores integer values like 1, 2, 3, 4
      float : stores decimal values like 1.2, 2.3, 3.4 , 4.5
      string : stores any any characters inclusing special characters, number and line breaks also
      boolean : True or False
      comple : 1+2j
      



4. What is an expression made up of? What do all expressions do?
Ans: An expression is made up of values, variables and operators. Expression will evaluate and return single value.



5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
Ans: An expression evaluates as per the operators used in it and returns single value of any data type like boolean, int, stirng.
     But assignment statements assigns the vlaue to the variables.


6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1
Ans : bacon =23



7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3

Ans : 'spamspamspam'
      'spamspamspam'
    


8. Why is eggs a valid variable name while 100 is invalid?
Ans: A variable must be sequence of characters may include number and '_'. But only number is not allowed as variable.
    Thats why 100 is invalid and eggs is valid.



9. What three functions can be used to get the integer, floating-point number, or string version of a value?
Ans : int() 
      float()
      string()


10. Why does this expression cause an error? How can you fix it?
'I have eaten ' + 99 + ' burritos.'

Ans : Operator '+' can only concatenate stings or do addition operation for numbers only.

'I have eaten ' , 99 , ' burritos.'

"""
